# %% [markdown]
# # 🌱 Carbon Emissions Estimation: ML for Climate Policy
#
# **Author:** Dean | Lead Data & AI Engineer
#
# **Government:** DCCEEW (Safeguard Mechanism), Clean Energy Regulator, NGER, Treasury
#
# Dataset: sklearn synthetic regression — NO dataset needed.
#
# ---

# %%
import warnings,time,numpy as np,pandas as pd,matplotlib.pyplot as plt,seaborn as sns
from sklearn.datasets import make_regression
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from sklearn.linear_model import Ridge
from sklearn.ensemble import RandomForestRegressor
warnings.filterwarnings('ignore');plt.style.use('seaborn-v0_8-whitegrid')
X_arr,y=make_regression(n_samples=2000,n_features=12,n_informative=9,noise=12,random_state=78)
names=['energy_consumption_mwh','fuel_type_mix','production_output','facility_age_years','equipment_efficiency','renewable_pct','process_heat_intensity','transport_emissions','fugitive_emissions','electricity_grid_factor','carbon_capture_installed','offset_credits_held']
df=pd.DataFrame(X_arr,columns=names);df['co2_tonnes']=y;tc='co2_tonnes'
print(f"Generated: {df.shape}");print(df[tc].describe())
fig,ax=plt.subplots(figsize=(8,5))
ax.hist(df[tc],bins=30,color='#27ae60',edgecolor='black',alpha=0.7)
ax.set_title('CO2 Emissions Distribution (tonnes)',fontweight='bold')
plt.tight_layout();plt.savefig('t.png',dpi=150);plt.show()
print("AU: Safeguard Mechanism covers 215 facilities emitting 100kt+ CO2/year.")
print("Net zero by 2050. 43% reduction target by 2030. NGER mandatory reporting.")
# Out:
# Generated: (2000, 13)
# count    2000.000000
# mean        1.144930
# std       170.060682
# min      -622.010798
# 25%      -111.375600
# 50%        -1.821737
# 75%       116.906157
# max       542.647621
# Name: co2_tonnes, dtype: float64
# AU: Safeguard Mechanism covers 215 facilities emitting 100kt+ CO2/year.
# Net zero by 2050. 43% reduction target by 2030. NGER mandatory reporting.

# %%
nums=[c2 for c2 in df.columns if c2!=tc];X=df[nums];y2=df[tc].values
try:
    from xgboost import XGBRegressor
except: XGBRegressor=None
try:
    from lightgbm import LGBMRegressor
except: LGBMRegressor=None
models={'Ridge':Ridge(alpha=1.0),'RF':RandomForestRegressor(n_estimators=100,random_state=42,n_jobs=-1)}
if XGBRegressor: models['XGB']=XGBRegressor(n_estimators=100,random_state=42,verbosity=0,n_jobs=-1)
if LGBMRegressor: models['LGBM']=LGBMRegressor(n_estimators=100,random_state=42,verbose=-1,n_jobs=-1,force_col_wise=True)
kf=KFold(3,shuffle=True,random_state=42);Xa=X.values;results={}
for mn,mod in models.items():
    fr,fm,f2=[],[],[];fp=np.zeros(len(y2))
    for fi,(ti,vi) in enumerate(kf.split(Xa)):
        m2=type(mod)(**mod.get_params());m2.fit(Xa[ti],y2[ti]);yp=m2.predict(Xa[vi]);fp[vi]=yp
        fr.append(np.sqrt(mean_squared_error(y2[vi],yp)));fm.append(mean_absolute_error(y2[vi],yp));f2.append(r2_score(y2[vi],yp))
    results[mn]={'rmse':np.mean(fr),'mae':np.mean(fm),'r2':np.mean(f2),'preds':fp}
    print(f"{mn}: RMSE={np.mean(fr):.2f} MAE={np.mean(fm):.2f} R2={np.mean(f2):.4f}")
best=max(results,key=lambda k:results[k]['r2']);print(f"Best: {best}")
bp=results[best]['preds']
fig,axes=plt.subplots(1,3,figsize=(16,4))
axes[0].scatter(y2,bp,alpha=0.3,s=5,color='#27ae60');axes[0].plot([y2.min(),y2.max()],[y2.min(),y2.max()],'r--');axes[0].set_title('Actual vs Predicted',fontweight='bold')
axes[1].hist(y2-bp,bins=25,color='#e74c3c',alpha=0.7);axes[1].set_title('Residuals',fontweight='bold')
tm={k:v for k,v in models.items() if k!='Ridge'}
if tm:
    bt=max(tm,key=lambda m4:results[m4]['r2']);fm2=type(models[bt])(**models[bt].get_params());fm2.fit(Xa,y2)
    fi=pd.DataFrame({'Feature':X.columns,'Imp':fm2.feature_importances_}).sort_values('Imp')
    axes[2].barh(fi['Feature'],fi['Imp'],color='#27ae60',edgecolor='black',linewidth=0.3);axes[2].set_title('Importance',fontweight='bold')
plt.tight_layout();plt.savefig('r.png',dpi=150);plt.show()
br=results[best];print(f"DEPLOYMENT: {best} R2={br['r2']:.4f} | NGER reporting -> Safeguard Mechanism compliance")
# Out:
# Ridge: RMSE=12.29 MAE=9.85 R2=0.9948
# RF: RMSE=65.70 MAE=50.24 R2=0.8501
# XGB: RMSE=54.98 MAE=41.98 R2=0.8947
# LGBM: RMSE=42.17 MAE=31.67 R2=0.9380
# Best: Ridge
# DEPLOYMENT: Ridge R2=0.9948 | NGER reporting -> Safeguard Mechanism compliance
